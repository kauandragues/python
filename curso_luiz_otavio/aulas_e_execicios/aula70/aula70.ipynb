# %% [markdown]
# # Aula 70
#
# Retorno de valores das funções (return)

# %%
variavel = print('kaua');
print(variavel)
# Out:
# kaua
# None

# %%
def soma(x, y):
    return x + y

soma = soma(3, 4)
print(soma)
# Out:
# 7

# %% [markdown]
# ## Código não acessivel

# %%
def soma2(x, y):
    return x + y
    soma4 = 1 + 2 # retorn para a 

print(soma2(3, 10))
# Out:
# 13
