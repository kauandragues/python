# %% [markdown]
# # Aula 88
#
# ## Valores Truthy e Falsy, Tipos Mutáveis e Imutáveis
# Mutáveis: `list []`,`dict {}`, `set()`
#
# Imutáveis: `tuple ()`, `string ""`, `int() 0`, `float() 0.0`, `None`, `bool False`, `range(0, 10)`

# %%
lista = []
dicionario = {}
conjunto = set()
tupla = ()
string = ''
inteiro = 0
flutuante = 0.0
nada = None
falso = False
intervalo = range(0)

def truthy(valor):
    return 'truthy' if valor else 'falsy'

print(f'{lista=}', truthy(lista))
print(f'{dicionario=}', truthy(dicionario))
print(f'{conjunto=}', truthy(conjunto))
print(f'{tupla=}', truthy(tupla))
print(f'{string=}', truthy(string))
print(f'{inteiro=}', truthy(inteiro))
print(f'{flutuante=}', truthy(flutuante))
print(f'{nada=}', truthy(nada))
print(f'{falso=}', truthy(falso))
print(f'{intervalo=}', truthy(intervalo))
# Out:
# lista=[] falsy
# dicionario={} falsy
# conjunto=set() falsy
# tupla=() falsy
# string='' falsy
# inteiro=0 falsy
# flutuante=0.0 falsy
# nada=None falsy
# falso=False falsy
# intervalo=range(0, 0) falsy
