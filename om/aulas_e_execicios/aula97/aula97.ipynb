# %% [markdown]
# # Modularização do seu próprio código
#
# O primeiro módulo executado chama-se `__main__`
#
# É possível importar outro módulo inteiro ou parte do módulo
#
# O Python conhece a pasta onde o `__main__` está e as pastas abaixo dele.
#
# Ele não conhece pastas e módulo acima do `__main__` por padrão
#
# O Python conhece todos os módulos e pacotes presentes nos caminhos de `sys.path`

# %%
print("Este módulo se chama", __name__)
# Out:
# Este módulo se chama __main__
