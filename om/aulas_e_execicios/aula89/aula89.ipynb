# %% [markdown]
# # Aula 89
#
# ## dir, hasattr e getattr

# %%
string = 'Kauã'
if hasattr(string, 'upper'):
    print('Existe upper')
    print(string.upper())
# Out:
# Existe upper
# KAUÃ

# %%
string = 'Kauã'
metodo = 'upper'

print(getattr(string, metodo)())
# Out:
# KAUÃ
